# %%
import pandas as pd

df1 = pd.read_excel("file3.xlsx")
df2 = pd.read_excel("file4.xlsx")

data = pd.concat([df1, df2])

data
# Out:
#       CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 2        48527         AL   Male   931  407  496     0  17743      0     65
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 1001     41537         FL      F   742  396  470     0  15356      7     37
# 1002      4881         FL      M   599  100  423     4  11670     10     27
# 1003     66358         ND      M   593  258  299     0  10186      1     70
# 1004      2231         WI   male   564  217  397     0  12315      0     96
# 1005     68534         MI      M   651  431  505     0  14845      7     77
#
#       IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
filtered2 = data[data['GENDER']=='F']
filtered2
# Out:
#       CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# 5        92293         IL      F  3359  878  973    87  35266     16     74
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 991      77441         WI      F   725  316  376     0  11623      1     86
# 993     117326         TX      F  1715  554  837    34  31480      3     54
# 996      66762         MI      F   632  279  388     2  12653      1     71
# 998     151175         CA      F  2707  507  537    80  16165     24     54
# 1001     41537         FL      F   742  396  470     0  15356      7     37
#
#       IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
data.head(10)
# Out:
#    CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    119966         TX      F   321  225  281     0   9372      3     68  264
# 1    152470         CA      F  5725  610  807    97  53158     13     22  763
# 2     48527         AL   Male   931  407  496     0  17743      0     65  502
# 3    171528         CA      F  1895  317  471    46  17431     10     62  389
# 4     50122  Tennessee      F   715  318  370     2  12416      0     75  340
# 5     92293         IL      F  3359  878  973    87  35266     16     74  897
# 6     47191         AL      F   950  264  378     3  20090      6     55  295
# 7     89288         IL      F  1243  414  507     9  15884     18     70  467
# 8    101676         MO      M  1162  529  612     7  18860      4     60  560
# 9     30051         GA      F   359  205  292     0   9279      0     90  260
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  243   8.058824      0  3212     T3      11.0
# ...

# %%
filtered2 = filtered2.reset_index(drop=True)
filtered2
# Out:
#      CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0      119966         TX      F   321  225  281     0   9372      3     68
# 1      152470         CA      F  5725  610  807    97  53158     13     22
# 2      171528         CA      F  1895  317  471    46  17431     10     62
# 3       50122  Tennessee      F   715  318  370     2  12416      0     75
# 4       92293         IL      F  3359  878  973    87  35266     16     74
# ..        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 979     77441         WI      F   725  316  376     0  11623      1     86
# 980    117326         TX      F  1715  554  837    34  31480      3     54
# 981     66762         MI      F   632  279  388     2  12653      1     71
# 982    151175         CA      F  2707  507  537    80  16165     24     54
# 983     41537         FL      F   742  396  470     0  15356      7     37
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
#filtered2.loc[100:200]

# %%
filtered2.iloc[[2,3,4,5]]
# Out:
#   File "<ipython-input-32-3e4313cbff16>", line 1
#     filtered2.iloc[[1:100],[2,3,4,5]]
#                      ^
# SyntaxError: invalid syntax
