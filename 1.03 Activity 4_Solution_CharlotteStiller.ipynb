# %%
import pandas as pd

df1 = pd.read_excel("file3.xlsx")
df2 = pd.read_excel("file4.xlsx")

data = pd.concat([df1, df2])

# %%
data.dtypes
# Out:
# CONTROLN      int64
# STATE        object
# GENDER       object
# HV1          object
# IC1           int64
# IC4           int64
# HVP1          int64
# IC5           int64
# POBC1         int64
# POBC2         int64
# IC2           int64
# IC3           int64
# AVGGIFT     float64
# TCODE         int64
# DOB           int64
# DOMAIN       object
# TARGET_D    float64
# dtype: object

# %%
data.select_dtypes("float","int64")
# Out:
#         AVGGIFT  TARGET_D
# 0      8.058824      11.0
# 1     23.727273      45.0
# 2      4.416667       3.0
# 3      6.705882       5.0
# 4      9.250000      10.0
# ...         ...       ...
# 1001  14.285714      50.0
# 1002   9.230769      10.0
# 1003   5.266667       5.0
# 1004  11.400000      14.0
# 1005   7.428571       9.0
#
# [2006 rows x 2 columns]

# %%
data['AVGGIFT'] =  pd.to_numeric(data["AVGGIFT"], errors='coerce')

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#       CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 2        48527         AL   Male   931  407  496     0  17743      0     65
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 996      66762         MI      F   632  279  388     2  12653      1     71
# 997       6443         FL      M   595  252  274     0  11132      8     11
# 998     151175         CA      F  2707  507  537    80  16165     24     54
# 999     151504         CA      M  2666  535  653    63  24745     22     45
# 1000     74303         MI      M   444  225  299     3  10088      1     86
#
#       IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...
