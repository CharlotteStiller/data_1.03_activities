# %%
import pandas as pd

df1 = pd.read_excel("file3.xlsx")
df2 = pd.read_excel("file4.xlsx")

# %%
data = pd.concat([df1, df2])

# %%
data
# Out:
#       CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 2        48527         AL   Male   931  407  496     0  17743      0     65
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 1001     41537         FL      F   742  396  470     0  15356      7     37
# 1002      4881         FL      M   599  100  423     4  11670     10     27
# 1003     66358         ND      M   593  258  299     0  10186      1     70
# 1004      2231         WI   male   564  217  397     0  12315      0     96
# 1005     68534         MI      M   651  431  505     0  14845      7     77
#
#       IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
data = data.drop(["DOB", "DOMAIN" ], axis=1)

# %%
data.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'TARGET_D'],
#       dtype='object')

# %%
#Rearrange the columns by placing columns ic2, ic3, ic4, ic5 before the column median_home_val
data=data[['CONTROLN', 'STATE', 'GENDER','IC1', 'IC2', 'IC3','IC4', 'IC5', 'HV1',  'HVP1', 'POBC1', 'POBC2', 'AVGGIFT', 'TCODE', 'TARGET_D']]

# %%
data.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'IC1', 'IC2', 'IC3', 'IC4', 'IC5', 'HV1',
#        'HVP1', 'POBC1', 'POBC2', 'AVGGIFT', 'TCODE', 'TARGET_D'],
#       dtype='object')

# %%
data[(data['GENDER']=='F') & (data['TARGET_D']<100)]
# Out:
#       CONTROLN      STATE GENDER  IC1  IC2  IC3  IC4    IC5   HV1  HVP1  \
# 0       119966         TX      F  225  264  243  281   9372   321     0
# 1       152470         CA      F  610  763  698  807  53158  5725    97
# 3       171528         CA      F  317  389  405  471  17431  1895    46
# 4        50122  Tennessee      F  318  340  352  370  12416   715     2
# 5        92293         IL      F  878  897  934  973  35266  3359    87
# ...        ...        ...    ...  ...  ...  ...  ...    ...   ...   ...
# 991      77441         WI      F  316  354  335  376  11623   725     0
# 993     117326         TX      F  554  750  626  837  31480  1715    34
# 996      66762         MI      F  279  336  339  388  12653   632     2
# 998     151175         CA      F  507  504  538  537  16165  2707    80
# 1001     41537         FL      F  396  424  450  470  15356   742     0
#
#       POBC1  POBC2    AVGGIFT  TCODE  TARGET_D
# 0         3     68   8.058824      0      11.0
# ...

# %%
data[(data['GENDER']=='M') & (data['STATE']=="FL")]
# Out:
#       CONTROLN STATE GENDER  IC1  IC2  IC3  IC4    IC5  HV1  HVP1  POBC1  \
# 30       35581    FL      M  296  377  360  473  16729  906     3      4
# 31       46358    FL      M  362  371  388  408  12806  715     0      6
# 38       41545    FL      M  373  392  417  436  14942  658     0     11
# 55       11284    FL      M  324  391  404  478  17408  934     9      4
# 59       25678    FL      M  302  339  335  365  12474  721     2      3
# ...        ...   ...    ...  ...  ...  ...  ...    ...  ...   ...    ...
# 962      36776    FL      M  319  360  358  379  12869  653     0     11
# 973       4881    FL      M  100  406  200  423  11670  599     4     10
# 992       6403    FL      M  311  272  324  313  12509  677     0      2
# 997       6443    FL      M  252  263  262  274  11132  595     0      8
# 1002      4881    FL      M  100  406  200  423  11670  599     4     10
#
#       POBC2    AVGGIFT  TCODE  TARGET_D
# 30       37  10.428571      1      15.0
# ...
